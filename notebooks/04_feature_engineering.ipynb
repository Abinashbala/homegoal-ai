# %% [markdown]
# # Notebook 04 — Feature Engineering
#
# **Project:** HomeGoal AI
# **Purpose:** Derive all analytical and modeling features from cleaned datasets.
#
# **Prerequisites:** Run `02_data_cleaning.ipynb` first.
#
# **Reference:** `docs/feature_engineering_plan.md`
#
# ---
# **Sections:**
# 1. Environment Setup
# 2. Group A — Time-Series Features (HPI)
# 3. Group A — Time-Series Features (CPI)
# 4. Group A — Time-Series Features (FX)
# 5. Scenario Parameter Derivation
# 6. Feature Validation
# 7. Save Feature Dataset

# %% [markdown]
# ## 1. Environment Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
print('Feature engineering environment ready.')

# %% [markdown]
# ## 2. Group A — HPI Features

# %%
# TODO: Compute HPI features from docs/feature_engineering_plan.md → Section A1
# Features to create:
#   hpi_qoq_growth, hpi_yoy_growth
#   hpi_cagr_full, hpi_cagr_5yr, hpi_cagr_3yr
#   hpi_rolling_4q_avg, hpi_rolling_4q_std
#   hpi_pre_covid_cagr, hpi_post_covid_cagr
pass

# %% [markdown]
# ## 3. Group A — CPI Features

# %%
# TODO: Compute CPI features from docs/feature_engineering_plan.md → Section A2
# Features to create:
#   cpi_rolling_3yr_avg, cpi_rolling_5yr_avg
#   cumulative_inflation_index
#   inflation_forecast_conservative / expected / optimistic
pass

# %% [markdown]
# ## 4. Group A — FX Features

# %%
# TODO: Compute FX features from docs/feature_engineering_plan.md → Section A3
# Features to create:
#   fx_mom_change, fx_yoy_change
#   fx_cagr_full, fx_cagr_3yr
#   fx_rolling_12m_avg, fx_rolling_12m_std
#   fx_volatility_band_upper, fx_volatility_band_lower
pass

# %% [markdown]
# ## 5. Scenario Parameter Derivation

# %%
# TODO: Derive and validate scenario parameter values
# Conservative / Expected / Optimistic for HPI, CPI, FX
# Reference: docs/feature_engineering_plan.md → Section E

SCENARIO_PARAMS = {
    'conservative': {
        'hpi_cagr': 0.03,
        'cpi_annual': 0.075,
        'fx_annual_growth': 0.02,
        'savings_rate': 0.03,
        'investment_return': 0.06,
    },
    'expected': {
        'hpi_cagr': 0.048,
        'cpi_annual': 0.060,
        'fx_annual_growth': 0.043,
        'savings_rate': 0.04,
        'investment_return': 0.09,
    },
    'optimistic': {
        'hpi_cagr': 0.070,
        'cpi_annual': 0.040,
        'fx_annual_growth': 0.065,
        'savings_rate': 0.05,
        'investment_return': 0.12,
    }
}

print('Scenario parameters defined.')
print(SCENARIO_PARAMS)

# %% [markdown]
# ## 6. Feature Validation

# %%
# TODO: Validate all computed features
# - Check for NaN propagation
# - Verify CAGR calculations manually
# - Check rolling window edge cases
pass

# %% [markdown]
# ## 7. Save Feature Dataset

# %%
# TODO: Save final feature dataset to processed/
# df_features.to_csv('../processed/features_annual.csv', index=False)
pass
